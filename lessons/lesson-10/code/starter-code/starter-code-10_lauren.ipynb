# %% [markdown]
# ### Cost Benefit Questions
#
# 1. How would you rephrase the business problem if your model was optimizing toward _precision_? i.e., How might the model behave differently, and what effect would it have?
# 2. How would you rephrase the business problem if your model was optimizing toward _recall_?
# 3. What would the most ideal model look like in this case?

# %% [markdown]
# ### Visualizing models over variables

# %%
# %matplotlib inline

# %%
import pandas as pd
import sklearn.linear_model as lm
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('../dataset/flight_delays.csv')
df = df.loc[df.DEP_DEL15.notnull()].copy()

# %%
df.head()
# Out:
#    DAY_OF_MONTH  DAY_OF_WEEK     FL_DATE UNIQUE_CARRIER  AIRLINE_ID CARRIER  \
# 0             1            4  2015-01-01             AA       19805      AA
# 1             1            4  2015-01-01             AA       19805      AA
# 2             1            4  2015-01-01             AA       19805      AA
# 3             1            4  2015-01-01             AA       19805      AA
# 4             1            4  2015-01-01             AA       19805      AA
#
#    ORIGIN_AIRPORT_ID  ORIGIN_AIRPORT_SEQ_ID  ORIGIN_CITY_MARKET_ID  \
# 0              12478                1247802                  31703
# 1              12892                1289203                  32575
# 2              12478                1247802                  31703
# 3              12892                1289203                  32575
# 4              11298                1129803                  30194
#
#    DEST_AIRPORT_ID  DEST_AIRPORT_SEQ_ID  DEST_CITY_MARKET_ID  CRS_DEP_TIME  \
# ...

# %%
df = df[df.DEP_DEL15.notnull()]
df = df.join(pd.get_dummies(df['CARRIER'], prefix='carrier'))
df = df.join(pd.get_dummies(df['DAY_OF_WEEK'], prefix='dow'))
model = lm.LogisticRegression() # runs the logistic regression model
features = [i for i in df.columns if 'dow_' in i] #shows features which are Day of the Week

# %%
df.shape
# Out:
# (458311, 37)

# %%
features += ['CRS_DEP_TIME']
model.fit(df[features[1:]], df['DEP_DEL15'])

df['probability'] = model.predict_proba(df[features[1:]]).T[1]

# %%
ax = plt.subplot(111)
colors = ['blue', 'green', 'red', 'purple', 'orange', 'brown']
for e, c in enumerate(colors):
    df[df[features[e]] == 1].plot(x='CRS_DEP_TIME', y='probability', kind='scatter', color = c, ax=ax)

ax.set(title='Probability of Delay\n Based on Day of Week and Time of Day')

# %% [markdown]
# ### Other Answers: visualizing Airline or the inverse

# %%
features = [i for i in df.columns if 'carrier_' in i]
features += ['CRS_DEP_TIME']
print features # shows you the carrier names which are the features
model.fit(df[features[1:]], df['DEP_DEL15']) #fits the model
# Out:
# ['carrier_AA', 'carrier_AS', 'carrier_B6', 'carrier_DL', 'carrier_EV', 'carrier_F9', 'carrier_HA', 'carrier_MQ', 'carrier_NK', 'carrier_OO', 'carrier_UA', 'carrier_US', 'carrier_VX', 'carrier_WN', 'CRS_DEP_TIME']
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
#after the doing the logistic regression, need to get the probabilities to plot

df['probability'] = model.predict_proba(df[features[1:]]).T[1] 

# use code below to plot the probabilities by airline

ax = plt.subplot(111)
colors = ['blue', 'green', 'red', 'purple', 'orange', 'brown','yellow','black','white']
for e, c in enumerate(colors):
    df[df[features[e]] == 1].plot(x='CRS_DEP_TIME', y='probability', kind='scatter', color = c, ax=ax)

ax.set(title='Probability of Delay\n Based on Day of Week and Time of Day')

# %% [markdown]
# ### Visualizing Performance Against Baseline

# %% [markdown]
# #### Visualizing AUC and comparing Models

# %%
from sklearn import dummy, metrics

# %%
model0 = dummy.DummyClassifier()
model0.fit(df[features[1:]], df['DEP_DEL15'])
df['probability_0'] = model0.predict_proba(df[features[1:]]).T[1]

model1 = lm.LogisticRegression()
model.fit(df[features[1:]], df['DEP_DEL15'])
df['probability_1'] = model.predict_proba(df[features[1:]]).T[1]

# %%
df.shape
# Out:
# (458311, 40)

# %%
ax = plt.subplot(111)
vals = metrics.roc_curve(df.DEP_DEL15, df.probability_0)
ax.plot(vals[0], vals[1])
vals = metrics.roc_curve(df.DEP_DEL15, df.probability_1)
ax.plot(vals[0], vals[1])

ax.set(title='Area Under the Curve for prediction delayed=1', ylabel='', xlabel='', xlim=(0, 1), ylim=(0, 1))
# Out:
# [(0, 1),
# ...
#  (0, 1),
# ...

# %%
# blue line = dummy
# green line = model. According to AUC metric the model is better

# %% [markdown]
# #### Visualizing Precision / Recall

# %%
df = df[df.DEP_DEL15.notnull()]
df = df.join(pd.get_dummies(df['CARRIER'], prefix='carrier'))
df = df.join(pd.get_dummies(df['DAY_OF_WEEK'], prefix='dow'))
model = lm.LogisticRegression() # runs the logistic regression model
features = [i for i in df.columns if 'dow_' in i] #shows features which are Day of the Week

# %%
features += ['CRS_DEP_TIME']
model.fit(df[features[1:]], df['DEP_DEL15'])

df['probability'] = model.predict_proba(df[features[1:]]).T[1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-92-df20da8391d2> in <module>()
#       1 features += ['CRS_DEP_TIME']
# ----> 2 model.fit(df[features[1:]], df['DEP_DEL15'])
#       3
#       4 df['probability'] = model.predict_proba(df[features[1:]]).T[1]
#
# /anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    2051         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2052             # either boolean or fancy integer index
# -> 2053             return self._getitem_array(key)
#    2054         elif isinstance(key, DataFrame):
#    2055             return self._getitem_frame(key)
#
# /anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_array(self, key)
#    2095             return self.take(indexer, axis=0, convert=False)
#    2096         else:
# ...

# %%
df
# Out:
#         DAY_OF_MONTH  DAY_OF_WEEK     FL_DATE UNIQUE_CARRIER  AIRLINE_ID  \
# 0                  1            4  2015-01-01             AA       19805
# 1                  1            4  2015-01-01             AA       19805
# 2                  1            4  2015-01-01             AA       19805
# 3                  1            4  2015-01-01             AA       19805
# 4                  1            4  2015-01-01             AA       19805
# 6                  1            4  2015-01-01             AA       19805
# 7                  1            4  2015-01-01             AA       19805
# 8                  1            4  2015-01-01             AA       19805
# 9                  1            4  2015-01-01             AA       19805
# 10                 1            4  2015-01-01             AA       19805
# 11                 1            4  2015-01-01             AA       19805
# 12                 1            4  2015-01-01             AA       19805
# ...

# %%
ax = plt.subplot(111)
vals = metrics.precision_recall_curve(df.DEP_DEL15, df.probability_0)
ax.plot(vals[0], vals[1])
vals = metrics.precision_recall_curve_curve(df.DEP_DEL15, df.probability_1)
ax.plot(vals[0], vals[1])

ax.set(title='Area Under the Curve for prediction delayed=1', ylabel='', xlabel='', xlim=(0, 1), ylim=(0, 1))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-84-390af1bb17b0> in <module>()
#       1 ax = plt.subplot(111)
# ----> 2 vals = metrics.precision_recall_curve(df.DEP_DEL15, df.probability_0)
#       3 ax.plot(vals[0], vals[1])
#       4 vals = metrics.precision_recall_curve_curve(df.DEP_DEL15, df.probability_1)
#       5 ax.plot(vals[0], vals[1])
#
# /anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in __getattr__(self, name)
#    2742             if name in self._info_axis:
#    2743                 return self[name]
# -> 2744             return object.__getattribute__(self, name)
#    2745
#    2746     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'probability_0'

# %%
# blue line - dummy
# green line - model using DOW, not very good at optimizing for precision if fix recall
# answer is not so clear which model is better. could be bc DOW is not a good predictor

# %% [markdown]
# #### Building My Own Model

# %%
import pandas as pd
import sklearn.linear_model as lm
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('../dataset/flight_delays.csv')
df = df.loc[df.DEP_DEL15.notnull()].copy()

# %%
df.head()
# Out:
#    DAY_OF_MONTH  DAY_OF_WEEK     FL_DATE UNIQUE_CARRIER  AIRLINE_ID CARRIER  \
# 0             1            4  2015-01-01             AA       19805      AA
# 1             1            4  2015-01-01             AA       19805      AA
# 2             1            4  2015-01-01             AA       19805      AA
# 3             1            4  2015-01-01             AA       19805      AA
# 4             1            4  2015-01-01             AA       19805      AA
#
#    ORIGIN_AIRPORT_ID  ORIGIN_AIRPORT_SEQ_ID  ORIGIN_CITY_MARKET_ID  \
# 0              12478                1247802                  31703
# 1              12892                1289203                  32575
# 2              12478                1247802                  31703
# 3              12892                1289203                  32575
# 4              11298                1129803                  30194
#
#    DEST_AIRPORT_ID  DEST_AIRPORT_SEQ_ID  DEST_CITY_MARKET_ID  CRS_DEP_TIME  \
# ...

# %%
df = df[df.DEP_DEL15.notnull()]
df = df.join(pd.get_dummies(df['CARRIER'], prefix='carrier'))
df = df.join(pd.get_dummies(df['DAY_OF_WEEK'], prefix='dow'))
df = df.join(pd.get_dummies(df['ORIGIN_AIRPORT_ID'], prefix='origin'))
model = lm.LogisticRegression() # runs the logistic regression model
features = [i for i in df.columns if 'origin_' in i] #shows features which are Day of the Week

# %%
df.shape
# Out:
# (458311, 349)

# %%
features += ['CRS_DEP_TIME']
model.fit(df[features[1:]], df['DEP_DEL15'])

df['probability'] = model.predict_proba(df[features[1:]]).T[1]

# %%
ax = plt.subplot(111)
colors = ['blue', 'green', 'red', 'purple', 'orange', 'brown']
for e, c in enumerate(colors):
    df[df[features[e]] == 1].plot(x='CRS_DEP_TIME', y='probability', kind='scatter', color = c, ax=ax)

ax.set(title='Probability of Delay\n Based on Origin Airport')
